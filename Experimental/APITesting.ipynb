# %%
import requests

# %%
r = requests.get('https://api.wynncraft.com/v3/guild/list/territory')
print(r.json())
# Out:
# {'Ragni': {'guild': {'uuid': '00ccf9d3-6670-4cd7-a447-f7fec684129d', 'name': 'Avicia', 'prefix': 'AVO'}, 'acquired': '2026-05-24T14:10:49.528000Z', 'location': {'start': [-955, -1415], 'end': [-756, -1748]}}, 'Ragni Main Entrance': {'guild': {'uuid': '00ccf9d3-6670-4cd7-a447-f7fec684129d', 'name': 'Avicia', 'prefix': 'AVO'}, 'acquired': '2026-05-24T09:17:18.976000Z', 'location': {'start': [-747, -1530], 'end': [-616, -1652]}}, 'Emerald Trail': {'guild': {'uuid': '00ccf9d3-6670-4cd7-a447-f7fec684129d', 'name': 'Avicia', 'prefix': 'AVO'}, 'acquired': '2026-05-24T09:18:00.268000Z', 'location': {'start': [-615, -1530], 'end': [-436, -1652]}}, 'Ragni North Entrance': {'guild': {'uuid': '00ccf9d3-6670-4cd7-a447-f7fec684129d', 'name': 'Avicia', 'prefix': 'AVO'}, 'acquired': '2026-05-24T14:11:39.951000Z', 'location': {'start': [-944, -1761], 'end': [-818, -1859]}}, 'Katoa Ranch': {'guild': {'uuid': '00ccf9d3-6670-4cd7-a447-f7fec684129d', 'name': 'Avicia', 'prefix': 'AVO'}, 'acquired': '2026-
# ...

# %%
data = r.json()
print(data['Ragni']['name'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 r['Ragni']['name']
#
# TypeError: 'Response' object is not subscriptable
